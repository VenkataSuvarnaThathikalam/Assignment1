# %%
pythontext= "Edukron Data Science and Data Engineering Batch 2026"
print(pythontext[0:7])
print(pythontext[-52:-44])
# Out:
# Edukron
# Edukron

# %%
print(pythontext[8:12])
print(pythontext[-44:-40])
# Out:
# Data
# Data

# %%
print(pythontext[13:20])
print(pythontext[-39:-32])
# Out:
# Science
# Science

# %%
print(pythontext[21:24])
print(pythontext[-31:-28])
# Out:
# and
# and

# %%
print(pythontext[25:42])
print(pythontext[-27:-10])
# Out:
# Data Engineering
# Data Engineering

# %%
print(pythontext[30:42])
print(pythontext[-22:-10])
# Out:
# Engineering
# Engineering

# %%
print(pythontext[42:48])
print(pythontext[-10:-5])
# Out:
# Batch
# Batch

# %%
print(pythontext[48:52])
print(pythontext[-4:])
# Out:
# 2026
# 2026

# %%
print(pythontext[13:29])
print(pythontext[-39:-23])
# Out:
# Science and Data
# Science and Data

# %%
print(pythontext[8:48])
print(pythontext[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
