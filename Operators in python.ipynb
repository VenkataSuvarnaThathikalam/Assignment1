# %% [markdown]
# Question 1:Write a program to calculate the square root of a number using the math module.

# %%
import math
num=int(input("enter the number:"))
print(math.sqrt(num))
# Out:
# enter the number:9
# 3.0

# %% [markdown]
# Question 2:Find the cube root of a given number using mathematical operations.

# %%
import math
num=int(input("Enter the given number:"))
cube_root=num**(1/2)
print("cube root of given number is:",cube_root)
# Out:
# Enter the given number:6
# cube root of given number is: 2.449489742783178

# %% [markdown]
# Question 3:Calculate the factorial of a number using math.factorial().

# %%
import math
num=int(input("Enter the number:"))
print(math.factorial(num))
# Out:
# Enter the number:4
# 24

# %% [markdown]
# Question 4:Find the GCD (Greatest Common Divisor) of two numbers using math.gcd()

# %%
import math
num1=int(input("Enter the given value:"))
num2=int(input("Enter the given value:"))
print(math.gcd(num1,num2))
# Out:
# Enter the given value:5
# Enter the given value:8
# 1

# %% [markdown]
# Question 5:Find the LCM of two numbers using math.lcm().

# %%
import math
num1=int(input("Enter the given value:"))
num2=int(input("Enter the given value:"))
print(math.lcm(num1,num2))
# Out:
# Enter the given value:9
# Enter the given value:3
# 9

# %% [markdown]
# Question 6:Calculate the value of 5 raised to the power of 8 using math.pow().

# %%
import math
num=int(input("Enter the given value:"))
print(math.pow(5,8))
# Out:
# Enter the given value:87
# 390625.0

# %% [markdown]
# Question 7:Find the absolute value of a negative decimal number using math.fabs().

# %%
import math
num=int(input("Enter the given value:"))
print(math.fabs(num))
# Out:
# Enter the given value:-56
# 56.0

# %% [markdown]
# Question 8:Round a floating-point number up using math.ceil().

# %%
import math
num=float(input("Enter the given value:"))
print(math.ceil(num))
# Out:
# Enter the given value:56.9
# 57

# %% [markdown]
# Question 9:Round a floating-point number down using math.floor().

# %%
import math
num=float(input("Enter the given value:"))
print(math.floor(num))
# Out:
# Enter the given value:34.7
# 34

# %% [markdown]
# Question 10:Round a floating-point number to the nearest integer using round().

# %%
import math
num=float(input("Enter the given number:"))
print(round(num))
# Out:
# Enter the given number:45.7
# 46

# %% [markdown]
# Question 11:Find the remainder of two numbers using math.fmod().

# %%
import math
num1=int(input("Enter the given value:"))
num2=int(input("Enter the given value:"))
print(math.fmod(num1,num2))
# Out:
# Enter the given value:17
# Enter the given value:38
# 17.0

# %% [markdown]
# Question 12:Find the quotient and remainder using divmod().

# %%
import math
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(divmod(num1,num2))
# Out:
# Enter the given number:34
# Enter the given number:12
# (2, 10)

# %% [markdown]
# Question 13:Calculate the sine, cosine, and tangent of 45 degrees.

# %%
import math
print(math.sin(45))
print(math.cos(45))
print(math.tan(45))
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %% [markdown]
# Question 14:Convert an angle from degrees to radians.

# %%
import math
print(math.radians(90))
# Out:
# 1.5707963267948966

# %% [markdown]
# Question 15:Convert an angle from radians to degrees.

# %%
import math
print(math.degrees(75))
# Out:
# 4297.183463481174

# %% [markdown]
# Question 16:Find the logarithm (base 10) of a number using math.log10().

# %%
import math
num=int(input("Enter the given number:"))
print(math.log10())
# Out:
# Enter the given number:34
# 2.302585092994046

# %% [markdown]
# Question 17: Find the natural logarithm of a number using math.log().

# %%
import math
num=int(input("Enter the given number:"))
print(math.log(num))
# Out:
# Enter the given number:65
# 4.174387269895637

# %% [markdown]
# Question 18:Calculate e raised to the power of x using math.exp().

# %%
import math
num=int(input("Enter the given number:"))
print(math.exp(num))
# Out:
# Enter the given number:25
# 72004899337.38588

# %% [markdown]
# Question 19:Find the value of π (pi) and Euler's number (e) from the math module.

# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %% [markdown]
# Question 20: Find the distance between two points using math.dist().

# %%
import math
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(math.dist(num1,num2))5
# Out:
# Enter the given number:12
# Enter the given number:5
# 7.0

# %% [markdown]
# Question 21:Calculate the hypotenuse of a right triangle using math.hypot().

# %%
import math
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(math.hypot(num1,num2))
# Out:
# Enter the given number:2
# Enter the given number:7
# 7.280109889280518

# %% [markdown]
# Question 22:Find the combination (nCr) using math.comb().

# %%
import math
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(math.comb(num1,num2))
# Out:
# Enter the given number:45
# Enter the given number:32
# 73006209045

# %% [markdown]
# Question 23:Find the permutation (nPr) using math.perm().

# %%
import math
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(math.perm(num1,num2))
# Out:
# Enter the given number:34
# Enter the given number:23
# 7396204080477496714356326400000

# %% [markdown]
# Question 24:Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan()

# %%
import math
num=int(input("Enter the given number:"))
print(math.isfinite(num))
print(math.isinf(num))
print(math.isnan(num))
# Out:
# Enter the given number:34
# True
# False
# False

# %% [markdown]
# Question 25:Find the product of all numbers in a list using math.prod()

# %%
import math
num=[5,9,6,3,7,8]
print(math.prod(num))
# Out:
# 45360

# %% [markdown]
# Question 26:Find the sum of square roots of all numbers in a list.

# %%
import math
num=[1,4,6,8,2,5]
print(math.fsum(num))
# Out:
# 26.0

# %% [markdown]
# Question 27:Find the largest integer less than or equal to the square root of a given number.

# %%
import math
num=int(input("Enter the given number:"))
print(math.floor(num))
# Out:
# Enter the given number:45
# 45

# %% [markdown]
# Question 28:Calculate compound interest using math.pow().

# %%
import math
p=int(input("Enter the given number:"))
r=int(input("Enter the given number:"))
t=int(input("Enter the given number:"))
amount=p*math.pow((1+r/100),t)
ci=amount-p
print(ci)
# Out:
# Enter the given number:10000
# Enter the given number:10
# Enter the given number:2
# 2100.000000000002

# %% [markdown]
# Question 29:Find the area and circumference of a circle using math.pi.

# %%
import math
radius=int(input("Enter the given number:"))
area=math.pi*radius*radius
circumference=2*math.pi*radius
print(area)
print(circumference)
# Out:
# Enter the given number:23
# 1661.9025137490005
# 144.51326206513048

# %% [markdown]
# Question 30:Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

# %%
import math
print("1.square root")
print("2.factorial")
print("3.logarithm")
print("4.power")
print("5.trigonometric functions")
print("6.GCD")
print("7.LCM")
choice=int(input("Enter the given number:"))
if choice==1:
  num=int(input("Enter the given sqrt number:"))
  print(math.sqrt(num))
elif choice==2:
  num=int(input("Enter the given  factorial number:"))
  print(math.factorial(num))
elif choice==3:
  num=int(input("Enter the given logarithm number:"))
  print(math.log(num))
elif choice==4:
  num1=int(input("Enter the given  pow1 number:"))
  num2=int(input("Enter the given pow2 number:"))
  print(math.pow(num1,num2))
elif choice==5:
  num1=int(input("Enter the given number:"))
  print(math.sin(45))
  print(math.cos(45))
  print(math.tan(45))
elif choice==6:
  num1=int(input("Enter the given gcd number:"))
  num2=int(input("Enter the given  gcd number:"))
  print(math.gcd(num1,num2))
elif choice==7:
  num1=int(input("Enter the given lcm number:"))
  num2=int(input("Enter the given lcm number:"))
  print(math.lcm(num1,num2))
else:
  print("Invalid")
# Out:
# 1.square root
# 2.factorial
# 3.logarithm
# 4.power
# 5.trigonometric functions
# 6.GCD
# 7.LCM
# Enter the given number:5
# Enter the given number:45
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %% [markdown]
# Arithmetic Operators

# %% [markdown]
# Question 1:Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(num1+num2)
print(num2-num2)
print(num1*num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
print(num1**num2)
# Out:
# Enter the given number:2
# Enter the given number:9
# 11
# 0
# 18
# 0.2222222222222222
# 0
# 2
# 512

# %% [markdown]
# Question 2:Swap two numbers without using a third variable.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
num1=num1+num2
num2=num1-num2
num1=num1-num2
print(num1)
print(num2)
# Out:
# Enter the given number:3
# Enter the given number:8
# 8
# 3

# %% [markdown]
# Question 3:Find whether a number is even or odd using the modulus operator.

# %%
num=int(input("Enter the given number:"))
if num%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter the given number:6
# Even

# %% [markdown]
# Question 4:Reverse a three-digit number using arithmetic operators

# %%
num=int(input("Enter the given number:"))
rev=0
while num>0:
  rem=num%10
  rev=rev*10+rem
  num=num//10
print(rev)
# Out:
# Enter the given number:456
# 654

# %% [markdown]
# Question 5:Find the last digit and first digit of a given number.

# %%
num=int(input("Enter the given number:"))
last_digit=num%10
first_digit=num//10
print(last_digit)
print(first_digit)
# Out:
# Enter the given number:65
# 5
# 6

# %% [markdown]
# Assignment Operators

# %% [markdown]
# Question 6:Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

# %%
num=int(input("Enter the given numbr:"))
x=num
print(x)
x+=num
print(x)
x-=num
print(x)
x*=num
print(x)
x/=num
print(x)
x//=num
print(x)
x%=num
print(x)
x**=num
print(x)
# Out:
# Enter the given numbr:5
# 5
# 10
# 5
# 25
# 5.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# Question 7:Update a bank account balance using compound assignment operators.

# %%
balance=int(input("Enter the given money:"))
x=balance
print(x)
x+=balance
print(x)
x-=balance
print(x)
x*=balance
print(x)
x/=balance
print(x)
x//=balance
print(x)
x%=balance
print(x)
x**=balance
print(x)
# Out:
# Enter the given money:10000
# 10000
# 20000
# 10000
# 100000000
# 10000.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# Question 8:Calculate the total marks using += inside a loop.

# %%
marks=int(input("Enter the number of subject: "))
total=0
for i in range(marks):
  num=int(input("Enter the given number:"))
  total+=num
print(total)
# Out:
# Enter the number of subject: 5
# Enter the given number:40
# Enter the given number:50
# Enter the given number:45
# Enter the given number:39
# Enter the given number:78
# 252

# %% [markdown]
# Comparison Operators

# %% [markdown]
# Question 9:Compare two numbers and print the larger number.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
if num1>num2:
  print(num1)
else:
  print(num2)
# Out:
# Enter the given number:67
# Enter the given number:98
# 98

# %% [markdown]
# Question 10:Check whether three numbers are equal.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
num3=int(input("Enter the given number:"))
if num1==num2==num3:
  print("Equal")
else:
  print("Not Equal")
# Out:
# Enter the given number:4
# Enter the given number:4
# Enter the given number:4
# Equal

# %% [markdown]
# Question 11:Find the largest among three numbers using comparison operators.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
num3=int(input("Enter the given number:"))
if num1>num2 and num1>num3:
  print(num1)
elif num2>num3 and num2>num1:
  print(num2)
else:
  print(num3)
# Out:
# Enter the given number:6
# Enter the given number:5
# Enter the given number:9
# 9

# %% [markdown]
# Question 12:Check whether a student is eligible to vote based on age.

# %%
age=int(input("Enter the given age:"))
if age>=18:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Enter the given age:23
# Eligible

# %% [markdown]
# Question 13:Check if a person is eligible for a loan (age > 21 AND salary > 30000).

# %%
age=int(input("Enter the given age:"))
salary=int(input("Enter the given salary:"))
if age>21 and salary>30000:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Enter the given age:25
# Enter the given salary:35000
# Eligible

# %% [markdown]
# Question 14:Check if a number lies between 10 and 100 using logical operators.

# %%
num=int(input("Enter the given number:"))
if num>10 and num<100:
  print("Between 10 and 100")
else:
  print("Not Between 10 and 100")
# Out:
# Enter the given number:67
# Between 10 and 100

# %% [markdown]
# Question 15:Validate username and password using logical operators.

# %%
username=str(input("Enter the username:"))
password=str(input("Enter the username:"))
if username=="abc" and password=="123":
  print("Valid")
else:
  print("Not valid")
# Out:
# Enter the username:abc
# Enter the username:123
# Valid

# %% [markdown]
# Question 16:Determine whether a year is a leap year using logical conditions.

# %%
year=int(input("Enter the given year:"))
if year%4==0 and year%100!=0 or year%400==0:
  print("Leap year")
else:
  print("Not leap year")
# Out:
# Enter the given year:2023
# Not leap year

# %% [markdown]
# Question 17:Find the bitwise AND, OR, XOR of two numbers.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print(num1&num2)
print(num1/num2)
print(num1^num2)
# Out:
# Enter the given number:6
# Enter the given number:9
# 0
# 0.6666666666666666
# 15

# %% [markdown]
# Question 18:Perform left shift and right shift operations.

# %%
num=8
print(num<<2)
print(num>>2)
# Out:
# 32
# 2

# %% [markdown]
# Question 19:Check whether a number is even using a bitwise operator.

# %%
num=int(input("Enter the given number:"))
if num&1==0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter the given number:7
# Odd

# %% [markdown]
# Question 20:Swap two numbers using the XOR operator.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
num1=num1^num2
num2=num1^num2
num1=num1^num2
print(num1)
print(num2)
# Out:
# Enter the given number:6
# Enter the given number:8
# 8
# 6

# %% [markdown]
# Question 21:Count how many bits are set to 1 in a number using bitwise operations.

# %%
num=int(input("Enter the given number:"))
count=0
while num>0:
  if num&1==1:
    count+=1
  num=num>>1
print(count)
# Out:
# Enter the given number:5
# 2

# %% [markdown]
# Question 22:Demonstrate the difference between is and ==.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
if num1 is num2:
  print("True")
else:
  print("False")
if num1==num2:
  print("True")
else:
  print("False")
# Out:
# Enter the given number:3
# Enter the given number:3
# True
# True

# %% [markdown]
# Question 23:Check whether two variables refer to the same list object.

# %%
list1=[10,20,30]
list2=list1
if list1 is list2:
  print("True ")
else:
  print("False")
# Out:
# True

# %% [markdown]
# Question 24:Show the behavior of is not with integers and lists.

# %%
a=int(input("Enter the given number:"))
b=int(input("Enter the given number:"))
print(a is not b)
list1=[10,20,30]
list2=[10,20,30]
print(a is not b)
# Out:
# Enter the given number:6
# Enter the given number:9
# True
# True

# %% [markdown]
# Membership Operators

# %% [markdown]
# Question 25:Check whether a character exists in a string.

# %%
ch=str(input("Enter the given character:"))
string=str(input("Enter the given string:"))
if ch in string:
  print("Exists")
else:
  print("Not Exists")
# Out:
# Enter the given character:varna
# Enter the given string:Suvarna
# Exists

# %% [markdown]
# Question 26:Check whether a number exists in a list.

# %%
list=[10,3,6,8]
num=int(input("Enter the given number:"))
if num in list:
  print("Exists")
else:
  print("Not Exists")
# Out:
# Enter the given number:9
# Not Exists

# %% [markdown]
# Question 27:Count how many vowels in a string belong to a predefined vowel list using in.

# %%
user_string = input("Enter the given string:")
vowels = "aeiouAEIOU"
count = 0
for char in user_string:
  if char in vowels:
    count += 1
print(count)
# Out:
# Enter the given string:Suvarna
# 3

# %% [markdown]
# Mixed Operator Programs

# %% [markdown]
# Build a simple calculator using arithmetic and comparison operators.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
print("Select the choice:")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
print("5.Floor Division")
print("6.Modulus")
print("7.Exponentiation")
choice=int(input("Enter the given number:"))
if choice==1:
  print(num1+num2)
elif choice==2:
  print(num1-num2)
elif choice==3:
  print(num1*num2)
elif choice==4:
  print(num1/num2)
elif choice==5:
  print(num1//num2)
elif choice==6:
  print(num1%num2)
elif choice==7:
  print(num1**num2)
else:
  print("Invalid")
# Out:
# Enter the given number:6
# Enter the given number:7
# Select the choice:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Floor Division
# 6.Modulus
# 7.Exponentiation
# Enter the given number:3
# 42

# %% [markdown]
# Question 29:Create a grading system using comparison and logical operators.

# %%
marks=float(input("Enter the given marks:"))
if marks>=90 and marks<=100:
  print("Grade A")
elif marks>=80 and marks<90:
  print("Grade B")
elif marks>=70 and marks<80:
  print("Grade c")
elif marks>=60 and marks>70:
  print("Grade D")
elif marks>=50 and marks>60:
  print("Grade E")
elif marks>=40 and marks>50:
  print("Grade F")
else:
  print("Fail")
# Out:
# Enter the given marks:56
# Grade F

# %% [markdown]
# Question 30:Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %%
num1=int(input("Enter the given number:"))
num2=int(input("Enter the given number:"))
while True:
  print("==========Menu========")
  print("1.Artimetic operations:")
  print("2.Comparison operations:")
  print("3.Logical operations:")
  print("4.Assignment operations:")
  print("5.Membership operations:")
  print("6.Identity operations:")
  print("7.Bitwise operations:")
  print("8.Exit")
  choice=int(input("Enter the given number:"))
  if choice==1:
    print("Arithmetic operators:")
    print("1.Addition: ",num1+num2)
    print("2.Subtraction: ",num1-num2)
    print("3:Multiplication: " ,num1*num2)
    print("4.Division: ",num1/num2)
    print("5.Floor Division: ",num1//num2)
    print("6.Modulus: ",num1%num2)
    print("7.Exponentiation: ",num1**num)
  elif choice==2:
    print("Comparison operators")
    print("num1==num2:" ,num1==num2)
    print("num1!=num2:" ,num1!=num2)
    print("num1>num2:" ,num1>num2)
    print("num1<num2:" ,num1<num2)
    print("num1>=num2:" ,num1>=num2)
    print("num1<=num2:" ,num1<=num2)
  elif choice==3:
    print("Logical opertors")
    print("num1>0 and num2>0: ",num1>0 and num2>0)
    print("num1>0 or num2>0: ",num1>0 or num2>0)
    print("not(num1>0):", not(num1>0))
  elif choice==4:
    print("Assignment operators")
    x=num1
    print(x)
    x+=num2
    print(x)
    x-=num2
    print(x)
    x*=num2
    print(x)
    x/=num2
    print(x)
    x//=num2
    print(x)
    x%=num2
    print(x)
    x**=num2
    print(x)
  elif choice==5:
    print("Membership operators")
    numbers=[10,20,30,40,50]
    print("List:",numbers)
    print("a is in list:" ,a in numbers)
    print("bis not in List:" ,b not in numbers)
  elif choice==6:
    print("Identity operators")
    print("num1 is num2:" ,num1 is num2)
    print("num1 is not num2:" ,num1 is not num2)
  elif choice==7:
    print("Bitwise operators")
    print("num1&num2:",num1&num2)
    print("num1|num2:",num1|num2)
    print("num1^num2:",num1^num2)
  elif choice==8:
    print(exit)
    break
  else:
    print("Invalid")
# Out:
# Enter the given number:54
# Enter the given number:65
# ==========Menu========
# 1.Artimetic operations:
# 2.Comparison operations:
# 3.Logical operations:
# 4.Assignment operations:
# 5.Membership operations:
# 6.Identity operations:
# 7.Bitwise operations:
# 8.Exit
# Enter the given number:2
# Comparison operators
# num1==num2: False
# num1!=num2: True
# num1>num2: False
# num1<num2: True
# num1>=num2: False
# num1<=num2: True
# ==========Menu========
# 1.Artimetic operations:
# 2.Comparison operations:
# 3.Logical operations:
# 4.Assignment operations:
# 5.Membership operations:
# 6.Identity operations:
# 7.Bitwise operations:
# 8.Exit
