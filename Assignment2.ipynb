# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000], ["C102", "Anita", "Current", 150000], ["C103", "Kiran", "Loan", 500000] ], [ ["C104", "Sneha", "Savings", 95000], ["C105", "Vikram", "Current", 275000], ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
print(bank)
# Out:
# [[[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]], [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]], [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]]

# %% [markdown]
# Print Rahul's complete record.

# %%
print(bank[0][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %% [markdown]
# Print Anita's account type

# %%
print(bank[0][0][1][2])
# Out:
# Current

# %% [markdown]
# Print Kiran's loan amount.

# %%
print(bank[0][0][2][3])
# Out:
# 500000

# %% [markdown]
# Print Sneha's customer ID.

# %%
print(bank[0][1][0][0])
# Out:
# C104

# %% [markdown]
# Print Vikram's balance.

# %%
print(bank[0][1][1][3])
# Out:
# 275000

# %% [markdown]
# Print Meena's complete record

# %%
print(bank[0][1][2])
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %% [markdown]
# Print Arjun's customer ID.

# %%
print(bank[1][0][0][0])
# Out:
# C201

# %% [markdown]
# Print Pooja's name.

# %%
print(bank[1][0][1][1])
# Out:
# Pooja

# %% [markdown]
# Print Ramesh's account type.

# %%
print(bank[1][0][2][2])
# Out:
# Loan

# %% [markdown]
# Print Priya's balance

# %%
print(bank[1][1][0][3])
# Out:
# 45000

# %% [markdown]
# Print Amit's account type.

# %%
print(bank[1][1][1][2])
# Out:
# Current

# %% [markdown]
# Print Divya's customer ID.

# %%
print(bank[1][1][2][0])
# Out:
# C206

# %% [markdown]
# Print Nikhil's account type.

# %%
print(bank[2][0][0][2])
# Out:
# Savings

# %% [markdown]
# Print Kavya's balance.

# %%
print(bank[2][0][1][3])
# Out:
# 240000

# %% [markdown]
# Print Suresh's loan amount.

# %%
print(bank[2][0][2][3])
# Out:
# 1000000

# %% [markdown]
# Print Neha's name.

# %%
print(bank[2][1][0][1])
# Out:
# Neha

# %% [markdown]
# Print Rohan's complete record

# %%
print(bank[2][1][1])
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# Print Asha's account type.

# %%
print(bank[2][1][2][2])
# Out:
# Loan

# %% [markdown]
# Print all customers in Bank 1, Branch 1

# %%
print(bank[0][0])
# Out:
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %% [markdown]
# Print all customers in Bank 1, Branch 2.

# %%
print(bank[0][1])
# Out:
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %% [markdown]
# Print all customers in Bank 2, Branch 1.

# %%
print(bank[1][0])
# Out:
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %% [markdown]
# Print all customers in Bank 2, Branch 2.

# %%
print(bank[1][1])
# Out:
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %% [markdown]
# Print all customers in Bank 3, Branch 1.

# %%
print(bank[2][0])
# Out:
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %% [markdown]
# Print all customers in Bank 3, Branch 2.

# %%
print(bank[2][1])
# Out:
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %% [markdown]
# Print all branches of Bank 1.

# %%
print(bank[0])
# Out:
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %% [markdown]
# Print all branches of Bank 2.

# %%
print(bank[1])
# Out:
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %% [markdown]
# Print all branches of Bank 3.

# %%
print(bank[2])
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %% [markdown]
# Print the first customer from every bank's first branch

# %%
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]

# %% [markdown]
# Print the second customer from every bank's second branch.

# %%
print(bank[0][1][1])
print(bank[1][1][1])
print(bank[2][1][1])
# Out:
# ['C105', 'Vikram', 'Current', 275000]
# ['C205', 'Amit', 'Current', 185000]
# ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# Print the loan amount of the last customer in Bank 3, Branch 2.

# %%
print(bank[2][1][2][3])
# Out:
# 550000

# %% [markdown]
# Create a list of 5 employee names and add a new employee using append().

# %%
names=["Suvarna","Ammala","Indra","Pravali","Lakshmi"]
names.append("Dinesh")
print(names)
# Out:
# ['Suvarna', 'Ammala', 'Indra', 'Pravali', 'Lakshmi', 'Dinesh']

# %% [markdown]
# Create a list of account numbers and add three new account numbers using extend().

# %%
numbers=[101,102,103,104,105]
numbers.extend([106,107,108])
print(numbers)
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %% [markdown]
# Insert a new customer at the beginning of a customer list using insert().

# %%
customer=["Suvarna","ammala","Pravali","Indra"]
customer.insert(0,"Dinu")
print(customer)
# Out:
# ['Dinu', 'Suvarna', 'ammala', 'Pravali', 'Indra']

# %% [markdown]
# Insert a transaction amount at index 3 in a list

# %%
amount=[100000,200000,300000,400000,600000,45000]
amount.insert(3,670000)
print(amount)
# Out:
# [100000, 200000, 300000, 670000, 400000, 600000, 45000]

# %% [markdown]
# Remove the last item from a list using pop()

# %%
Cities = ["Bangalore", "Hyderabad", "Chennai", "Pune"]
Cities.pop(-1)
print(Cities)
# Out:
# ['Bangalore', 'Hyderabad', 'Chennai']

# %% [markdown]
# Remove the customer "Rahul" from a customer list using remove().

# %%
customers = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
customers.remove("Rahul")
print(customers)
# Out:
# ['Anita', 'Kiran', 'Sneha', 'Vikram']

# %% [markdown]
# Count how many times the account type "Savings" appears in a list using count().

# %%
account_types = ["Savings", "Current", "Loan","Savings"]
account_types.count("Savings")
# Out:
# 2

# %% [markdown]
# Find the index of "Current" in a list of account types using index().

# %%
account_types = ["Savings", "Current", "Loan"]
account_types.index("Current")
# Out:
# 1

# %% [markdown]
# Reverse a list of transaction IDs using reverse().

# %%
transaction_ids = [101, 102, 103, 104, 105]
transaction_ids.reverse()
print(transaction_ids)
# Out:
# [105, 104, 103, 102, 101]

# %% [markdown]
# Sort a list of account balances in ascending order using sort().

# %%
balances = [85000, 120000, 45000, 95000, 275000]
balances.sort()
print(balances)
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %% [markdown]
# Sort a list of customer names in descending order using sort().

# %%
new_customers = ["Amit", "Priya", "Rahul", "Divya"]
new_customers.sort(reverse=True)
print(new_customers)
# Out:
# ['Rahul', 'Priya', 'Divya', 'Amit']

# %% [markdown]
# Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.

# %%
numbers=[1,2,3,4,5,6]
new=numbers.copy()
new[5]=10
print(numbers,new)
# Out:
# [1, 2, 3, 4, 5, 6] [1, 2, 3, 4, 5, 10]

# %% [markdown]
# Clear all elements from a list using clear().

# %%
balances = [85000, 120000, 45000, 95000, 275000]
balances.clear()
print(balances)
# Out:
# []

# %% [markdown]
# Append a nested list containing a new customer's details to an existing customer list.

# %%
a=[["Suvarna",301,4000000],["Indra",302,5000000]]
b=["Pravali",303,6000000]
a.append(b)
print(a)
# Out:
# [['Suvarna', 301, 4000000], ['Indra', 302, 5000000], ['Pravali', 303, 6000000]]

# %% [markdown]
# Extend a list of branch names with another list of new branches.

# %%
bank_branches = ["MG Road", "Indiranagar", "Whitefield", "Electronic City"]
new_branches=["Marathalli","Kalyanagar"]
bank_branches.extend(new_branches)
print(bank_branches)
# Out:
# ['MG Road', 'Indiranagar', 'Whitefield', 'Electronic City', 'Marathalli', 'Kalyanagar']

# %% [markdown]
# Remove the first occurrence of the balance 50000 from a list using remove().

# %%
balances = [85000, 120000, 45000,50000, 95000, 275000]
balances.remove(50000)
print(balances)
# Out:
# [85000, 120000, 45000, 95000, 275000]

# %% [markdown]
# Pop the element at index 2 from a list and print the removed value.

# %%
a=[1,2,3,4,5,6,7]
a.pop(2)
print(a)
# Out:
# [1, 2, 4, 5, 6, 7]

# %% [markdown]
# Count how many times the city "Bangalore" appears in a list.

# %%
cities = ["Bangalore", "Hyderabad", "Chennai", "Pune"]
cities=cities.count("Bangalore")
print(cities)
# Out:
# 1

# %% [markdown]
# Reverse a list of bank names and print the result.

# %%
names=["SBI","BOB","Axis","Canara"]
names.reverse()
print(names)
# Out:
# ['Canara', 'Axis', 'BOB', 'SBI']

# %% [markdown]
# Create a list of loan amounts and sort it in descending order.

# %%
balances = [85000, 120000, 45000, 95000, 275000]
balances.sort(reverse=True)
print(balances)
# Out:
# [275000, 120000, 95000, 85000, 45000]

# %% [markdown]
# Basic Operations

# %% [markdown]
# bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}
#
# customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
#
# new_customers = {"Amit", "Priya", "Rahul", "Divya"}
#
# loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
#
# savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
#
# transaction_ids = {101, 102, 103, 104, 105}
#
# balances = {85000, 120000, 45000, 95000, 275000}
#
# cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
# new_cities = {"Mumbai", "Bangalore", "Delhi"}
#
# account_types = {"Savings", "Current", "Loan"}

# %% [markdown]
# Print the customers set.

# %%
print(customers)
# Out:
# {'Sneha', 'Anita', 'Vikram', 'Kiran', 'Rahul'}

# %% [markdown]
# Find the number of elements in the customers set.

# %%
print(len(customers))
# Out:
# 5

# %% [markdown]
# Check whether "Rahul" exists in the customers set

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(customers.intersection({'Rahul'}))
# Out:
# {'Rahul'}

# %% [markdown]
# Check whether "Meena" exists in the `customers` set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(customers.intersection({'Meena'}))
# Out:
# set()

# %% [markdown]
# Iterate through all elements in the `bank_branches` set.

# %%
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}
for i in bank_branches:
  print(i)
# Out:
# Electronic City
# Whitefield
# MG Road
# Indiranagar

# %% [markdown]
# . Add "Meena" to the `customers` set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.add("Meena")
print(customers)
# Out:
# {'Sneha', 'Meena', 'Anita', 'Vikram', 'Kiran', 'Rahul'}

# %% [markdown]
# Add "Mysore" to the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.add("Mysore")
print(cities)
# Out:
# {'Chennai', 'Bangalore', 'Mysore', 'Pune', 'Hyderabad'}

# %% [markdown]
# Update the customers set with new_customers.

# %%
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.update(new_customers)
print(customers)
# Out:
# {'Anita', 'Divya', 'Priya', 'Sneha', 'Amit', 'Meena', 'Rahul', 'Vikram', 'Kiran'}

# %% [markdown]
# Update the cities set with new_cities.

# %%
new_cities = {"Mumbai", "Bangalore", "Delhi"}
cities.update(new_cities)
print(cities)
# Out:
# {'Mumbai', 'Chennai', 'Delhi', 'Bangalore', 'Mysore', 'Pune', 'Hyderabad'}

# %% [markdown]
# Remove "Rahul" from the customers set

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.remove("Rahul")
print(customers)
# Out:
# {'Sneha', 'Anita', 'Vikram', 'Kiran'}

# %% [markdown]
# Remove "Pune" from the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.remove("Pune")
print(cities)
# Out:
# {'Chennai', 'Hyderabad', 'Bangalore'}

# %% [markdown]
# Discard "Anita" from the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.discard("Anita")
print(customers)
# Out:
# {'Sneha', 'Vikram', 'Kiran', 'Rahul'}

# %% [markdown]
# Discard "Delhi" from the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard("Delhi")
print(cities)
# Out:
# {'Chennai', 'Hyderabad', 'Bangalore', 'Pune'}

# %% [markdown]
# Discard "Kolkata" from the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard("Kolkata")
print(cities)
# Out:
# {'Chennai', 'Hyderabad', 'Bangalore', 'Pune'}

# %% [markdown]
# Remove a random element from the transaction_ids set using pop().

# %%
transaction_ids = {101, 102, 103, 104, 105}
transaction_ids.pop()
print(transaction_ids)
# Out:
# {102, 103, 104, 105}

# %% [markdown]
# Remove another random element from the account_types set.

# %%
account_types = {"Savings", "Current", "Loan"}
account_types.pop()
print(account_types)
# Out:
# {'Loan', 'Current'}

# %% [markdown]
# Remove all elements from the balances set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
balances.clear()
print(balances)
# Out:
# set()

# %% [markdown]
# Create a copy of the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
print(customers_copy)
# Out:
# {'Sneha', 'Anita', 'Vikram', 'Kiran', 'Rahul'}

# %% [markdown]
# Modify the copied set and verify that the original set remains unchanged.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
customers_copy.add("Meena")
print(customers,customers_copy)
# Out:
# {'Sneha', 'Anita', 'Vikram', 'Kiran', 'Rahul'} {'Sneha', 'Meena', 'Anita', 'Vikram', 'Kiran', 'Rahul'}

# %% [markdown]
# Find the union of customers and new_customers.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.union(new_customers))
# Out:
# {'Anita', 'Divya', 'Priya', 'Sneha', 'Amit', 'Rahul', 'Vikram', 'Kiran'}

# %% [markdown]
# Find the common customers between customers and new_customers.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.intersection(new_customers))
# Out:
# {'Rahul'}

# %% [markdown]
# Find customers who have both Savings and Loan accounts.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
print(customers.intersection(savings_customers,loan_customers))
# Out:
# {'Rahul'}

# %% [markdown]
# Find customers present only in customers but not in new_customers.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.difference(new_customers)
# Out:
# {'Anita', 'Kiran', 'Sneha', 'Vikram'}

# %% [markdown]
# Find customers who have only Savings accounts.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
print(savings_customers.difference(loan_customers))
# Out:
# {'Sneha', 'Nikhil', 'Priya'}

# %% [markdown]
# Find customers that are present in either customers or new_customers but not both.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.symmetric_difference(new_customers))
# Out:
# {'Kiran', 'Divya', 'Vikram', 'Sneha', 'Amit', 'Anita', 'Priya'}

# %% [markdown]
# Check whether {"Rahul", "Kiran"} is a subset of loan_customers.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
print({"Rahul", "Kiran"}.issubset(loan_customers))
# Out:
# True

# %% [markdown]
# Check whether customers is a superset of {"Rahul", "Anita"}.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(customers.issuperset({"Rahul", "Anita"}))
# Out:
# True

# %% [markdown]
# Check whether loan_customers and new_cities are disjoint.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
new_cities = {"Mumbai", "Bangalore", "Delhi"}
print(loan_customers.isdisjoint(new_cities))
# Out:
# True

# %% [markdown]
# Find the maximum balance in the balances set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(max(balances))
# Out:
# 275000

# %% [markdown]
# Find the minimum balance in the balances set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(min(balances))
# Out:
# 45000

# %% [markdown]
# Find the total of all balances.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sum(balances))
# Out:
# 620000

# %% [markdown]
# Sort the balances set in ascending order.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sorted(balances))
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %% [markdown]
# Convert the customers set into a list.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(list(customers))
# Out:
# ['Kiran', 'Sneha', 'Rahul', 'Anita', 'Vikram']

# %% [markdown]
# Convert the cities set into a tuple.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
print(tuple(cities))
# Out:
# ('Bangalore', 'Hyderabad', 'Chennai', 'Pune')

# %% [markdown]
# Remove duplicates from the list: ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"] by converting it into a set.

# %%
customer = ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
print(set(customer))
# Out:
# {'Sneha', 'Rahul', 'Anita'}

# %% [markdown]
# Create an empty set.

# %%
empty_set = set()
print(empty_set)
type(empty_set)
# Out:
# set()
# set

# %% [markdown]
# Add five employee names to the empty set.

# %%
employee=set()
employee.add("Suvarna")
employee.add("Indra")
employee.add("Pravali")
employee.add("Lakshmi")
employee.add("Dinesh")
print(employee)
# Out:
# {'Lakshmi', 'Dinesh', 'Suvarna', 'Indra', 'Pravali'}

# %% [markdown]
# Find the length of the account_types set.

# %%
account_types = {"Savings", "Current", "Loan"}
print(len(account_types))
# Out:
# 3

# %% [markdown]
# Print every element of the loan_customers set using a loop.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
for i in loan_customers:
  print(i)
# Out:
# Kiran
# Rahul
# Asha
# Ramesh

# %% [markdown]
# Clear the transaction_ids set and verify that it is empty.

# %%
transaction_ids = {101, 102, 103, 104, 105}
transaction_ids.clear()
print(transaction_ids)
# Out:
# set()
